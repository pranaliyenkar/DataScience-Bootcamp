# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn import svm 
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#loading data
#data_df = pd.read_csv("C:\Users\piyus\Downloads\DataScience-Bootcamp-main\DataScience-Bootcamp-main\clf (4)\heart_failure_clinical_records_dataset.csv")
#data_df.head()
data_df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
cmap = sns.diverging_palette(2, 165, s=80, l=55, n=9)
corrmat = data_df.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <AxesSubplot: >

# %%
# Checking for potential outliers using the "Boxen and Swarm plots" of non binary features.
cols= ["#CD5C5C","#FF0000"]
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature: 
    plt.figure(figsize=(10,7))
    sns.swarmplot(x=data_df["DEATH_EVENT"], y=data_df[i], color="black", alpha=0.7)
    sns.boxenplot(x=data_df["DEATH_EVENT"], y=data_df[i], palette=cols)
    plt.show()
# Out:
# C:\Users\piyus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3544: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\piyus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3544: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
X=data_df.drop(["DEATH_EVENT"],axis=1)
y=data_df["DEATH_EVENT"]

# %%
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_scaled= s_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=col_names)   
X_scaled.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
X_train, X_test, y_train,y_test = train_test_split(X_scaled,y,test_size=0.30,random_state=25)

# %%
#### SVM
model1=svm.SVC()

# Fitting the model 
model1.fit (X_train, y_train)

# Predicting the test variables
y_pred = model1.predict(X_test)

# Getting the score 
model1.score (X_test, y_test)
# Out:
# 0.7888888888888889

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84        60
#            1       0.69      0.67      0.68        30
#
#     accuracy                           0.79        90
#    macro avg       0.76      0.76      0.76        90
# weighted avg       0.79      0.79      0.79        90

# %%
###Artificial Neural Network (ANN) 
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 25, epochs = 80,callbacks=[early_stopping], validation_split=0.25)
# Out:
# Epoch 1/80
# 7/7 [==============================] - 3s 72ms/step - loss: 0.6928 - accuracy: 0.6026 - val_loss: 0.6913 - val_accuracy: 0.8302
# Epoch 2/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6921 - accuracy: 0.6346 - val_loss: 0.6893 - val_accuracy: 0.8302
# Epoch 3/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6913 - accuracy: 0.6346 - val_loss: 0.6875 - val_accuracy: 0.8302
# Epoch 4/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6905 - accuracy: 0.6346 - val_loss: 0.6859 - val_accuracy: 0.8302
# Epoch 5/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6899 - accuracy: 0.6346 - val_loss: 0.6838 - val_accuracy: 0.8302
# Epoch 6/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6890 - accuracy: 0.6346 - val_loss: 0.6821 - val_accuracy: 0.8302
# Epoch 7/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6882 - accuracy: 0.6346 - val_loss: 0.6800 - val_accuracy: 0.8302
# Epoch 8/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6872 - accuracy: 0.6346 - val_loss: 0.6778 - val_accuracy: 0.8302
# Epoch 9/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6863 - accuracy: 0.6346 - val_loss: 0.6756 - val_accuracy: 0.8302
# Epoch 10/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6854 - accuracy: 0.6346 - val_loss: 0.6732 - val_accuracy: 0.8302
# Epoch 11/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6829 - accuracy: 0.6346 - val_loss: 0.6701 - val_accuracy: 0.8302
# Epoch 12/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6814 - accuracy: 0.6346 - val_loss: 0.6662 - val_accuracy: 0.8302
# Epoch 13/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6796 - accuracy: 0.6346 - val_loss: 0.6620 - val_accuracy: 0.8302
# Epoch 14/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6745 - accuracy: 0.6346 - val_loss: 0.6573 - val_accuracy: 0.8302
# Epoch 15/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6704 - accuracy: 0.6538 - val_loss: 0.6507 - val_accuracy: 0.8302
# Epoch 16/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6655 - accuracy: 0.6410 - val_loss: 0.6425 - val_accuracy: 0.8302
# Epoch 17/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6529 - accuracy: 0.6987 - val_loss: 0.6328 - val_accuracy: 0.8491
# Epoch 18/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6511 - accuracy: 0.7115 - val_loss: 0.6216 - val_accuracy: 0.8302
# Epoch 19/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6455 - accuracy: 0.7308 - val_loss: 0.6093 - val_accuracy: 0.8868
# Epoch 20/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6144 - accuracy: 0.7756 - val_loss: 0.5939 - val_accuracy: 0.9057
# Epoch 21/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6060 - accuracy: 0.7756 - val_loss: 0.5783 - val_accuracy: 0.8868
# Epoch 22/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5884 - accuracy: 0.8013 - val_loss: 0.5601 - val_accuracy: 0.8868
# Epoch 23/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5699 - accuracy: 0.8077 - val_loss: 0.5395 - val_accuracy: 0.9057
# Epoch 24/80
# 7/7 [==============================] - 0s 19ms/step - loss: 0.5502 - accuracy: 0.8269 - val_loss: 0.5184 - val_accuracy: 0.9057
# Epoch 25/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.
80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4388 - accuracy: 0.8462 - val_loss: 0.3352 - val_accuracy: 0.8491
# Epoch 57/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3810 - accuracy: 0.8590 - val_loss: 0.3324 - val_accuracy: 0.8491
# Epoch 58/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4301 - accuracy: 0.8397 - val_loss: 0.3325 - val_accuracy: 0.8491
# Epoch 59/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4367 - accuracy: 0.8269 - val_loss: 0.3347 - val_accuracy: 0.8491
# Epoch 60/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4303 - accuracy: 0.8397 - val_loss: 0.3382 - val_accuracy: 0.8302
# Epoch 61/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4121 - accuracy: 0.8590 - val_loss: 0.3435 - val_accuracy: 0.8302
# Epoch 62/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4114 - accuracy: 0.8462 - val_loss: 0.3561 - val_accuracy: 0.8302
# Epoch 63/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3948 - accuracy: 0.8333 - val_loss: 0.3663 - val_accuracy: 0.8302
# Epoch 64/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4534 - accuracy: 0.8269 - val_loss: 0.3710 - val_accuracy: 0.8302
# Epoch 65/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4006 - accuracy: 0.8333 - val_loss: 0.3754 - val_accuracy: 0.8302
# Epoch 66/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3916 - accuracy: 0.8590 - val_loss: 0.3709 - val_accuracy: 0.8302
# Epoch 67/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4120 - accuracy: 0.8654 - val_loss: 0.3668 - val_accuracy: 0.8302
# Epoch 68/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4159 - accuracy: 0.8526 - val_loss: 0.3597 - val_accuracy: 0.8302
# Epoch 69/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3844 - accuracy: 0.8590 - val_loss: 0.3531 - val_accuracy: 0.8302
# Epoch 70/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4018 - accuracy: 0.8654 - val_loss: 0.3547 - val_accuracy: 0.8302
# Epoch 71/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3629 - accuracy: 0.8590 - val_loss: 0.3549 - val_accuracy: 0.8302
# Epoch 72/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3885 - accuracy: 0.8526 - val_loss: 0.3525 - val_accuracy: 0.8302
# Epoch 73/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4502 - accuracy: 0.8782 - val_loss: 0.3486 - val_accuracy: 0.8302
# Epoch 74/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4173 - accuracy: 0.8333 - val_loss: 0.3444 - val_accuracy: 0.8302
# Epoch 75/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3996 - accuracy: 0.8397 - val_loss: 0.3336 - val_accuracy: 0.8679
# Epoch 76/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3812 - accuracy: 0.8333 - val_loss: 0.3303 - val_accuracy: 0.8679
# Epoch 77/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3988 - accuracy: 0.8397 - val_loss: 0.3282 - val_accuracy: 0.8679
# Epoch 78/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.4340 - accuracy: 0.8654 - val_loss: 0.3334 - val_accuracy: 0.8491
# Epoch 79/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4060 - accuracy: 0.8590 - val_loss: 0.3355 - val_accuracy: 0.8491
# Epoch 80/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3327 - accuracy: 0.8846 - val_loss: 0.3373 - val_accuracy: 0.8491

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy is', val_accuracy*100))
# Out:
# val_accuracy is: 85.14%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#EE6C6C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.4)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.81        60
#            1       0.62      0.77      0.69        30
#
#     accuracy                           0.77        90
#    macro avg       0.74      0.77      0.75        90
# weighted avg       0.79      0.77      0.77        90
